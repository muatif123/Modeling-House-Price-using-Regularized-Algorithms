# %%
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats
from scipy.stats import norm, skew
from sklearn import preprocessing
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNetCV, ElasticNet
from xgboost import XGBRegressor, plot_importance 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x))

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (1460, 81)

# %%
(df.isnull().sum() / len(df)).sort_values(ascending = False)[:20]
# Out:
# PoolQC         0.995
# MiscFeature    0.963
# Alley          0.938
# Fence          0.808
# FireplaceQu    0.473
# LotFrontage    0.177
# GarageYrBlt    0.055
# GarageCond     0.055
# GarageType     0.055
# GarageFinish   0.055
# GarageQual     0.055
# BsmtFinType2   0.026
# BsmtExposure   0.026
# BsmtQual       0.025
# BsmtCond       0.025
# BsmtFinType1   0.025
# MasVnrArea     0.005
# MasVnrType     0.005
# Electrical     0.001
# Id             0.000
# dtype: float64

# %%
df.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'Id'], axis = 1, inplace = True)

# %%
df['SalePrice'].describe()
# Out:
# count     1460.000
# mean    180921.196
# std      79442.503
# min      34900.000
# 25%     129975.000
# 50%     163000.000
# 75%     214000.000
# max     755000.000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(df['SalePrice'] , fit = norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(df['SalePrice'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc = 'best')
plt.ylabel('Frequency')
plt.title('Sale Price distribution')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['SalePrice'], plot = plt)
plt.show();
# Out:
#  mu = 180921.20 and sigma = 79415.29

# %%
sns.distplot(np.log1p(df['SalePrice']) , fit = norm);

# Get the fitted parameters used by the function
(mu, sigma) = norm.fit(np.log1p(df['SalePrice']))
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc = 'best')
plt.ylabel('Frequency')
plt.title('log(Sale Price+1) distribution')

#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(np.log1p(df['SalePrice']), plot = plt)
plt.show();
# Out:
#  mu = 12.02 and sigma = 0.40

# %% [markdown]
# ### Correlation between numeric features

# %%
pd.set_option('precision', 2)
plt.figure(figsize = (10, 8))
sns.heatmap(df.drop(['SalePrice'],axis = 1).corr(), square = True)
plt.suptitle("Pearson Correlation Heatmap")
plt.show();

# %% [markdown]
# There exists strong correlations between some of the features. For example, GarageYrBlt and YearBuilt, TotRmsAbvGrd and GrLivArea, GarageArea and GarageCars are strongly correlated. They actually express more or less the same thing. I will let ElasticNetCV to help reduce redundancy.

# %% [markdown]
# ### Correlation between SalePrice  and the other numeric features

# %%
corr_with_sale_price = df.corr()["SalePrice"].sort_values(ascending = False)
plt.figure(figsize = (14, 6))
corr_with_sale_price.drop("SalePrice").plot.bar()
plt.show();

# %% [markdown]
# The correlation of Sale Price with OverallQual is the greatest (around 0.8). Also GrLivArea presents a correlation of over 0.7, and GarageCars presents a correlation of over 0.6.

# %%
sns.pairplot(df[['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars']])
plt.show();

# %% [markdown]
# Log transform the target feature and all the other skewed numerical features.

# %%
df["SalePrice"] = np.log1p(df["SalePrice"])

#log transform skewed numeric features:
numeric_feats = df.dtypes[df.dtypes != "object"].index

skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())) #compute skewness
skewed_feats = skewed_feats[skewed_feats > 0.75]
skewed_feats = skewed_feats.index

df[skewed_feats] = np.log1p(df[skewed_feats])

# %%
df = pd.get_dummies(df)
df = df.fillna(df.mean())

# %%
X, y = df.drop(['SalePrice'], axis = 1), df['SalePrice']

X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size = 0.2, random_state = 123)

# %% [markdown]
# ### ElasticNetCV

# %%
cv_model = ElasticNetCV(l1_ratio = [.1, .5, .7, .9, .95, .99, 1], eps = 1e-3, n_alphas = 100, fit_intercept = True, 
                        normalize = True, precompute = 'auto', max_iter = 2000, tol = 0.0001, cv = 6, 
                        copy_X = True, verbose = 0, n_jobs = -1, positive = False, random_state = 123)

# %%
cv_model.fit(X_train, y_train)
# Out:
# ElasticNetCV(cv=6, l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=2000,
#              n_jobs=-1, normalize=True, random_state=123)

# %%
print('Optimal alpha: %.8f'%cv_model.alpha_)
print('Optimal l1_ratio: %.3f'%cv_model.l1_ratio_)
print('Number of iterations %d'%cv_model.n_iter_)
# Out:
# Optimal alpha: 0.00020896
# Optimal l1_ratio: 0.700
# Number of iterations 72

# %%
y_train_pred = cv_model.predict(X_train)
y_pred = cv_model.predict(X_test)
print('Train r2 score: ', r2_score(y_train_pred, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred))
train_mse = mean_squared_error(y_train_pred, y_train)
test_mse = mean_squared_error(y_pred, y_test)
train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)
print('Train RMSE: %.4f' % train_rmse)
print('Test RMSE: %.4f' % test_rmse)
# Out:
# Train r2 score:  0.9175646859417228
# Test r2 score:  0.926887205778146
# Train RMSE: 0.1065
# Test RMSE: 0.1042

# %%
feature_importance = pd.Series(index = X_train.columns, data = np.abs(cv_model.coef_))

n_selected_features = (feature_importance>0).sum()
print('{0:d} features, reduction of {1:2.2f}%'.format(
    n_selected_features,(1-n_selected_features/len(feature_importance))*100))

feature_importance.sort_values().tail(30).plot(kind = 'bar', figsize = (12,5));
# Out:
# 103 features, reduction of 62.55%

# %% [markdown]
# ### Xgboost

# %%
xgb_model1 = XGBRegressor()
xgb_model1.fit(X_train, y_train, verbose = False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
y_train_pred1 = xgb_model1.predict(X_train)
y_pred1 = xgb_model1.predict(X_test)

print('Train r2 score: ', r2_score(y_train_pred1, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred1))
train_mse1 = mean_squared_error(y_train_pred1, y_train)
test_mse1 = mean_squared_error(y_pred1, y_test)
train_rmse1 = np.sqrt(train_mse1)
test_rmse1 = np.sqrt(test_mse1)
print('Train RMSE: %.4f' % train_rmse1)
print('Test RMSE: %.4f' % test_rmse1)
# Out:
# Train r2 score:  0.999530717854501
# Test r2 score:  0.895338753080377
# Train RMSE: 0.0087
# Test RMSE: 0.1247

# %%
xgb_model2 = XGBRegressor(n_estimators = 1000)
xgb_model2.fit(X_train, y_train, early_stopping_rounds = 5, 
             eval_set = [(X_test, y_test)], verbose = False)
y_train_pred2 = xgb_model2.predict(X_train)
y_pred2 = xgb_model2.predict(X_test)

print('Train r2 score: ', r2_score(y_train_pred2, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred2))
train_mse2 = mean_squared_error(y_train_pred2, y_train)
test_mse2 = mean_squared_error(y_pred2, y_test)
train_rmse2 = np.sqrt(train_mse2)
test_rmse2 = np.sqrt(test_mse2)
print('Train RMSE: %.4f' % train_rmse2)
print('Test RMSE: %.4f' % test_rmse2)
# Out:
# Train r2 score:  0.9897989839965418
# Test r2 score:  0.894017578733619
# Train RMSE: 0.0401
# Test RMSE: 0.1255

# %% [markdown]
# It was an improvement!

# %%
xgb_model3 = XGBRegressor(n_estimators=1000, learning_rate=0.05)
xgb_model3.fit(X_train, y_train, early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)], verbose=False)
y_train_pred3 = xgb_model3.predict(X_train)
y_pred3 = xgb_model3.predict(X_test)

print('Train r2 score: ', r2_score(y_train_pred3, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred3))
train_mse3 = mean_squared_error(y_train_pred3, y_train)
test_mse3 = mean_squared_error(y_pred3, y_test)
train_rmse3 = np.sqrt(train_mse3)
test_rmse3 = np.sqrt(test_mse3)
print('Train RMSE: %.4f' % train_rmse3)
print('Test RMSE: %.4f' % test_rmse3)
# Out:
# Train r2 score:  0.9867206881008407
# Test r2 score:  0.9093345175438512
# Train RMSE: 0.0454
# Test RMSE: 0.1160

# %% [markdown]
# There was no improvement.

# %%
xgb_model4 = XGBRegressor(n_estimators = 100, learning_rate = 0.08, gamma = 0, subsample = 0.75,
                         colsample_bytree = 1, max_depth = 7, n_jobs = -1)
xgb_model4.fit(X_train,y_train)
y_train_pred4 = xgb_model4.predict(X_train)
y_pred4 = xgb_model4.predict(X_test)

print('Train r2 score: ', r2_score(y_train_pred4, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred4))
train_mse4 = mean_squared_error(y_train_pred4, y_train)
test_mse4 = mean_squared_error(y_pred4, y_test)
train_rmse4 = np.sqrt(train_mse4)
test_rmse4 = np.sqrt(test_mse4)
print('Train RMSE: %.4f' % train_rmse4)
print('Test RMSE: %.4f' % test_rmse4)
# Out:
# Train r2 score:  0.9861426909457216
# Test r2 score:  0.9121586023748103
# Train RMSE: 0.0462
# Test RMSE: 0.1142

# %% [markdown]
# I concluded that xgb_model2 is the best model.

# %%
from collections import OrderedDict
OrderedDict(sorted(xgb_model2.get_booster().get_fscore().items(), key = lambda t: t[1], reverse = True))
# Out:
# OrderedDict([('LotArea', 85.0),
#              ('LotFrontage', 84.0),
#              ('MSSubClass', 77.0),
#              ('GrLivArea', 61.0),
#              ('BsmtUnfSF', 50.0),
#              ('OverallCond', 45.0),
#              ('OverallQual', 43.0),
#              ('MoSold', 41.0),
#              ('GarageArea', 40.0),
#              ('TotalBsmtSF', 39.0),
#              ('YearRemodAdd', 38.0),
#              ('YearBuilt', 34.0),
#              ('OpenPorchSF', 33.0),
#              ('BsmtFinSF1', 29.0),
#              ('GarageYrBlt', 28.0),
#              ('2ndFlrSF', 23.0),
#              ('1stFlrSF', 21.0),
#              ('WoodDeckSF', 20.0),
#              ('MasVnrArea', 16.0),
#              ('EnclosedPorch', 16.0),
#              ('YrSold', 14.0),
#              ('FullBath', 12.0),
#              ('TotRmsAbvGrd', 12.0),
#              ('BsmtFullBath', 11.0),
#              ('ScreenPorch', 9.0),
#              ('Condition1_Artery', 9.0),
#              ('BsmtFinSF2', 8.0),
#              ('SaleCondition_Abnorml', 8.0),
#              ('Fireplaces', 6.0),
#              ('GarageCars', 6.0),
#              ('MSZoning_C (all)', 6.0),
#              ('HouseStyle_1.5Fin', 6.0),
#              ('Exterior1st_BrkFace', 6.0),
#              ('Functional_Typ', 6.0),
#              ('SaleCondition_Family', 6.0),
#              ('Neighborhood_Crawfor', 5.0),
#              ('Neighborhood_NAmes', 5.0),
#              ('Condition1_Norm', 5.0),
#              ('GarageType_Attchd', 5.0),
#              ('HalfBath', 4.0),
#              ('BedroomAbvGr', 4.0),
#              ('MSZoning_FV', 4.0),
#              ('LotShape_IR1', 4.0),
#              ('LandContour_Bnk', 4.0),
#              ('HouseStyle_SLvl', 4.0),
#              ('Exterior1st_Wd Sdng', 4.0),
#              ('BsmtExposure_Gd', 4.0),
#              ('BsmtFinType1_ALQ', 4.0),
#              ('HeatingQC_Gd', 4.0),
#              ('HeatingQC_TA', 4.0),
#              ('KitchenQual_Ex', 4.0),
#              ('PavedDrive_Y', 4.0),
#              ('LowQualFinSF', 3.0),
#              ('PoolArea', 3.0),
#              ('MSZoning_RM', 3.0),
#              ('LotConfig_FR2', 3.0),
#              ('Neighborhood_BrkSide', 3.0),
#              ('Neighborhood_Edwards', 3.0),
#              ('Neighborhood_Sawyer', 3.0),
#              ('BldgType_Duplex', 3.0),
#              ('Exterior1st_HdBoard', 3.0),
#              ('Exterior1st_MetalSd', 3.0),
#              ('Exterior2nd_CmentBd', 3.0),
#              ('ExterQual_Gd', 3.0),
#              ('BsmtExposure_Av', 3.0),
#              ('BsmtFinType2_LwQ', 3.0),
#              ('CentralAir_N', 3.0),
#              ('GarageFinish_Fin', 3.0),
#              ('GarageFinish_RFn', 3.0),
#              ('GarageFinish_Unf', 3.0),
#              ('GarageQual_Fa', 3.0),
#              ('LandContour_HLS', 2.0),
#              ('LandContour_Low', 2.0),
#              ('LotConfig_Corner', 2.0),
#              ('LotConfig_CulDSac', 2.0),
#              ('LotConfig_Inside', 2.0),
#              ('Neighborhood_CollgCr', 2.0),
#              ('Neighborhood_StoneBr', 2.0),
#              ('Condition1_Feedr', 2.0),
#              ('Condition1_PosA', 2.0),
#              ('Condition1_RRAe', 2.0),
#              ('RoofStyle_Gambrel', 2.0),
#              ('Exterior1st_AsbShng', 2.0),
#              ('Exterior1st_BrkComm', 2.0),
#              ('Exterior2nd_MetalSd', 2.0),
#              ('Exterior2nd_Wd Sdng', 2.0),
#              ('Foundation_BrkTil', 2.0),
#              ('BsmtQual_Gd', 2.0),
#              ('BsmtQual_TA', 2.0),
#              ('BsmtCond_TA', 2.0),
#              ('BsmtExposure_Mn', 2.0),
#              ('BsmtExposure_No', 2.0),
#              ('BsmtFinType1_BLQ', 2.0),
#              ('BsmtFinType1_Rec', 2.0),
#              ('Heating_OthW', 2.0),
#              ('HeatingQC_Ex', 2.0),
#              ('Electrical_SBrkr', 2.0),
#              ('KitchenQual_Gd', 2.0),
#              ('KitchenQual_TA', 2.0),
#              ('Functional_Mod', 2.0),
#              ('FireplaceQu_Fa', 2.0),
#              ('FireplaceQu_Gd', 2.0),
#              ('FireplaceQu_TA', 2.0),
#              ('GarageType_BuiltIn', 2.0),
#              ('GarageType_Detchd', 2.0),
#              ('SaleType_COD', 2.0),
#              ('SaleCondition_Partial', 2.0),
#              ('KitchenAbvGr', 1.0),
#              ('3SsnPorch', 1.0),
#              ('MSZoning_RL', 1.0),
#              ('LotShape_IR2', 1.0),
#              ('LotShape_Reg', 1.0),
#              ('LandContour_Lvl', 1.0),
#              ('LandSlope_Gtl', 1.0),
#              ('Neighborhood_ClearCr', 1.0),
#              ('Neighborhood_IDOTRR', 1.0),
#              ('Neighborhood_MeadowV', 1.0),
#              ('Neighborhood_Mitchel', 1.0),
#              ('Neighborhood_NWAmes', 1.0),
#              ('Neighborhood_NoRidge', 1.0),
#              ('Neighborhood_NridgHt', 1.0),
#              ('Neighborhood_OldTown', 1.0),
#              ('Neighborhood_SWISU', 1.0),
#              ('Neighborhood_SawyerW', 1.0),
#              ('Neighborhood_Timber', 1.0),
#              ('Neighborhood_Veenker', 1.0),
#              ('Condition1_PosN', 1.0),
#              ('Condition2_Norm', 1.0),
#              ('BldgType_1Fam', 1.0),
#              ('HouseStyle_1Story', 1.0),
#              ('RoofStyle_Hip', 1.0),
#              ('RoofMatl_WdShngl', 1.0),
#              ('Exterior1st_Plywood', 1.0),
#              ('Exterior1st_Stucco', 1.0),
#              ('Exterior2nd_AsbShng', 1.0),
#              ('Exterior2nd_BrkFace', 1.0),
#              ('Exterior2nd_HdBoard', 1.0),
#              ('Exterior2nd_Plywood', 1.0),
#              ('Exterior2nd_Stucco', 1.0),
#              ('MasVnrType_BrkFace', 1.0),
#              ('ExterQual_TA', 1.0),
#              ('ExterCond_Fa', 1.0),
#              ('Foundation_Wood', 1.0),
#              ('BsmtQual_Ex', 1.0),
#              ('BsmtQual_Fa', 1.0),
#              ('BsmtCond_Fa', 1.0),
#              ('BsmtFinType1_GLQ', 1.0),
#              ('BsmtFinType2_Unf', 1.0),
#              ('HeatingQC_Fa', 1.0),
#              ('KitchenQual_Fa', 1.0),
#              ('Functional_Maj2', 1.0),
#              ('Functional_Min2', 1.0),
#              ('FireplaceQu_Po', 1.0),
#              ('GarageQual_Gd', 1.0),
#              ('GarageCond_Fa', 1.0),
#              ('SaleType_ConLD', 1.0),
#              ('SaleType_New', 1.0),
#              ('SaleType_Oth', 1.0),
#              ('SaleCondition_Alloca', 1.0),
#              ('SaleCondition_Normal', 1.0)])

# %%
most_relevant_features = list( dict((k, v) for k, v in xgb_model2.get_booster().get_fscore().items() if v >= 4).keys())
print(most_relevant_features)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 'ScreenPorch', 'MoSold', 'YrSold', 'MSZoning_C (all)', 'MSZoning_FV', 'LotShape_IR1', 'LandContour_Bnk', 'Neighborhood_Crawfor', 'Neighborhood_NAmes', 'Condition1_Artery', 'Condition1_Norm', 'HouseStyle_1.5Fin', 'HouseStyle_SLvl', 'Exterior1st_BrkFace', 'Exterior1st_Wd Sdng', 'BsmtExposure_Gd', 'BsmtFinType1_ALQ', 'HeatingQC_Gd', 'HeatingQC_TA', 'KitchenQual_Ex', 'Functional_Typ', 'GarageType_Attchd', 'PavedDrive_Y', 'SaleCondition_Abnorml', 'SaleCondition_Family']

# %%
train_x = df[most_relevant_features]
train_y = df['SalePrice']
X_train, X_test, y_train, y_test  = train_test_split(train_x, train_y, test_size = 0.2, random_state = 123)

# %%
xgb_model5 = XGBRegressor(n_estimators = 1000)
xgb_model5.fit(X_train, y_train, early_stopping_rounds = 5, 
             eval_set = [(X_test, y_test)], verbose = False)
y_train_pred5 = xgb_model5.predict(X_train)
y_pred5 = xgb_model5.predict(X_test)

print('Train r2 score: ', r2_score(y_train_pred5, y_train))
print('Test r2 score: ', r2_score(y_test, y_pred5))
train_mse5 = mean_squared_error(y_train_pred5, y_train)
test_mse5 = mean_squared_error(y_pred5, y_test)
train_rmse5 = np.sqrt(train_mse5)
test_rmse5 = np.sqrt(test_mse5)
print('Train RMSE: %.4f' % train_rmse5)
print('Test RMSE: %.4f' % test_rmse5)
# Out:
# Train r2 score:  0.9961081152251168
# Test r2 score:  0.8976587675502032
# Train RMSE: 0.0249
# Test RMSE: 0.1233
